# %% [markdown]
# ## Megatutorial 2

# %%
from pandas import read_csv

# %%
read_csv("fake_profiles.csv")
# Out:
#      Unnamed: 0 profile_pic  ...  num_follows  is_fake
# 0             0         yes  ...          955       no
# 1             1         yes  ...          533       no
# 2             2         yes  ...           98       no
# 3             3         yes  ...          651       no
# 4             4         yes  ...          126       no
# ..          ...         ...  ...          ...      ...
# 571         571         yes  ...          596      yes
# 572         572         yes  ...           75      yes
# 573         573         yes  ...          339      yes
# 574         574         yes  ...           73      yes
# 575         575         yes  ...          487      yes
#
# [576 rows x 13 columns]
