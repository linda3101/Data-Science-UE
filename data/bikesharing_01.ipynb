# %% [markdown]
# # Lektion 0: Einführung in Pandas

# %%
import pandas as pd
from pandas import read_csv

# %%
data = read_csv(
    filepath_or_buffer="../data/bikesharing.csv",
    sep=",",
    decimal=".",
)

# %%
data
# Out:
#      Unnamed: 0  season holiday weekday workingday weathersit      temp  \
# 0             0  spring      no     Sat         no     cloudy  0.344167
# 1             1  spring      no     Sun         no     cloudy  0.363478
# 2             2  spring      no     Mon         no  clear sky  0.196364
# 3             3  spring      no     Tue         no  clear sky  0.200000
# 4             4  spring      no     Wed         no  clear sky  0.226957
# ..          ...     ...     ...     ...        ...        ...       ...
# 726         726  spring      no     Thu         no     cloudy  0.254167
# 727         727  spring      no     Fri         no     cloudy  0.253333
# 728         728  spring      no     Sat         no     cloudy  0.253333
# 729         729  spring      no     Sun         no  clear sky  0.255833
# 730         730  spring      no     Mon         no     cloudy  0.215833
#
#         atemp       hum  windspeed  casual  registered   cnt  day  month  year
# ...
